# %% [markdown]
# This notebook show some basic use of the framework.

# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/35_geemap_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>

# %% [markdown]
# # Install packages
#
# `pip install -r requirement.txt`

# %% [markdown]
# # import packages

# %%
import math
import unittest
import json

import helper
import street_mapping as sm
# import rasterio
from PIL import Image

import matplotlib.pyplot as plt
import matplotlib.image as mpimg


# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Show the stop sign image

# %%
img_file = r'.\test_images\stop_signs\zuvhBGvbpULD4v9KMt8Dpg_39.5762479_-76.499666_0_287.75fov=20.jpg'
img_pil = mpimg.imread(img_file)
plt.imshow(img_pil)

# %%
detection_file = r'.\test_images\stop_signs\zuvhBGvbpULD4v9KMt8Dpg_39.5762479_-76.499666_0_287.75fov=20.txt'
bearing_deg = 287.75
img_detection = sm.Image_detection(detection_file=detection_file)
img_detection.compute_distance(bar_length_dict={0:0.75}, fov_h_deg=20)
img_detection.compute_offset(bearing_deg=bearing_deg)

# img_detection.save()
img_detection.detection_df[['distance', 'distance_z', 'offset_x', 'offset_y', 'bearing_rad', 'fov_h_deg', 'bar_length']]
# Out:
#    distance  distance_z   offset_x  offset_y  bearing_rad  fov_h_deg  \
# 0  16.88193    0.453488 -16.078279  5.146698     5.022185         20
#
#    bar_length
# 0        0.75
